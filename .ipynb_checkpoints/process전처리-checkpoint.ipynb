# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action="ignore")

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mpl
mpl.rcParams["axes.unicode_minus"] = False


import urllib.request as req
from urllib.request import urlopen
from urllib.error import HTTPError,URLError
import urllib.parse
from bs4 import BeautifulSoup
import requests

# %%
maket = pd.read_excel("data/marketing.xlsx",index_col ="기업명",thousands = ",") 
maket.head(16)
# Out:
#              1Q2017       2Q2017        3Q2017        4Q2017       1Q2018  \
# 기업명
# 넥슨      31730000000  36500000000   51220000000   59100000000  56310000000
# 엔씨소프트   12701000000  24115000000   22043000000   24151000000  10771000000
# 넷마블     78400000000  82400000000  101000000000  119400000000  74700000000
# 카카오게임즈  24959000000  21929000000   33460000000   36130000000  47941000000
# NHN      2043700000   2087900000    2069000000    2176100000   1593400000
# 컴투스     12020000000  19007000000   13900000000   21300000000  13300000000
# 데브시스터즈   1432000000    325000000      92000000     621000000     34000000
# 그라비티     3007770750   3007770750    3007770750    3007770750   4136462000
# 펄어비스     1254000000   1220000000    1455000000    5212000000  10506000000
# 웹젠       1831000000   2528000000     970000000    1669000000   1735000000
# 네오위즈     3140000000   3153000000    3844000000    3742000000   4217000000
# 위메이드     9059000000   1015000000     563000000     757000000    666000000
# ...

# %%
############### 왜인진 모르겠는데 데이터 불러오고나서 마지막에 이름없는 빈 컬럼이 있길래 지웠습니다

maket.info()

del maket["Unnamed: 20"]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 넥슨 to 베스파
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   1Q2017       16 non-null     int64
#  1   2Q2017       16 non-null     int64
#  2   3Q2017       16 non-null     int64
#  3   4Q2017       16 non-null     int64
#  4   1Q2018       16 non-null     int64
#  5   2Q2018       16 non-null     int64
#  6   3Q2018       16 non-null     int64
#  7   4Q2018       16 non-null     int64
#  8   1Q2019       16 non-null     int64
#  9   2Q2019       16 non-null     int64
#  10  3Q2019       16 non-null     int64
#  11  4Q2019       16 non-null     int64
#  12  1Q2020       16 non-null     int64
#  13  2Q2020       16 non-null     int64
#  14  3Q2020       16 non-null     int64
#  15  4Q2020       16 non-null     int64
#  16  1Q2021       15 non-null     float64
#  17  2Q2021       15 non-null     float64
#  18  3Q2021       15 non-null     float64
# ...

# %%
maket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 넥슨 to 베스파
# Data columns (total 19 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1Q2017  16 non-null     int64
#  1   2Q2017  16 non-null     int64
#  2   3Q2017  16 non-null     int64
#  3   4Q2017  16 non-null     int64
#  4   1Q2018  16 non-null     int64
#  5   2Q2018  16 non-null     int64
#  6   3Q2018  16 non-null     int64
#  7   4Q2018  16 non-null     int64
#  8   1Q2019  16 non-null     int64
#  9   2Q2019  16 non-null     int64
#  10  3Q2019  16 non-null     int64
#  11  4Q2019  16 non-null     int64
#  12  1Q2020  16 non-null     int64
#  13  2Q2020  16 non-null     int64
#  14  3Q2020  16 non-null     int64
#  15  4Q2020  16 non-null     int64
#  16  1Q2021  15 non-null     float64
#  17  2Q2021  15 non-null     float64
#  18  3Q2021  15 non-null     float64
# dtypes: float64(3), int64(16)
# memory usage: 2.5+ KB

# %%
#기업 별 합계 그래프

maket["합계"] = maket["1Q2017"]+ maket["2Q2017"]+ maket["3Q2017"]+ maket["4Q2017"]+ maket["1Q2018"]+ maket["2Q2018"]+ maket["3Q2018"]+ maket["4Q2018"]+ maket["1Q2019"]+ maket["2Q2019"]+ maket["3Q2019"]+ maket["4Q2019"]+maket["1Q2020"]+ maket["2Q2020"]+ maket["3Q2020"]+ maket["4Q2020"]+maket["1Q2021"]+ maket["2Q2021"]+ maket["3Q2021"]

########## maket.loc[:,"합계"] = maket.sum(axis = 1)  이런 방식도 간편할 것 같아요

# %%
maket
# Out:
#              1Q2017       2Q2017        3Q2017        4Q2017       1Q2018  \
# 기업명
# 넥슨      31730000000  36500000000   51220000000   59100000000  56310000000
# 엔씨소프트   12701000000  24115000000   22043000000   24151000000  10771000000
# 넷마블     78400000000  82400000000  101000000000  119400000000  74700000000
# 카카오게임즈  24959000000  21929000000   33460000000   36130000000  47941000000
# NHN      2043700000   2087900000    2069000000    2176100000   1593400000
# 컴투스     12020000000  19007000000   13900000000   21300000000  13300000000
# 데브시스터즈   1432000000    325000000      92000000     621000000     34000000
# 그라비티     3007770750   3007770750    3007770750    3007770750   4136462000
# 펄어비스     1254000000   1220000000    1455000000    5212000000  10506000000
# 웹젠       1831000000   2528000000     970000000    1669000000   1735000000
# 네오위즈     3140000000   3153000000    3844000000    3742000000   4217000000
# 위메이드     9059000000   1015000000     563000000     757000000    666000000
# ...

# %%
maket.sort_values(by="합계", ascending=False).head(16)
# Out:
#              1Q2017       2Q2017        3Q2017        4Q2017       1Q2018  \
# 기업명
# 넷마블     78400000000  82400000000  101000000000  119400000000  74700000000
# 카카오게임즈  24959000000  21929000000   33460000000   36130000000  47941000000
# 넥슨      31730000000  36500000000   51220000000   59100000000  56310000000
# 엔씨소프트   12701000000  24115000000   22043000000   24151000000  10771000000
# 컴투스     12020000000  19007000000   13900000000   21300000000  13300000000
# 펄어비스     1254000000   1220000000    1455000000    5212000000  10506000000
# 네오위즈     3140000000   3153000000    3844000000    3742000000   4217000000
# 베스파      1977658500   1977658500    1977658500    1977658500   9300195250
# 위메이드     9059000000   1015000000     563000000     757000000    666000000
# 데브시스터즈   1432000000    325000000      92000000     621000000     34000000
# 웹젠       1831000000   2528000000     970000000    1669000000   1735000000
# 게임빌      1866000000   4056000000    1190000000    4299000000   4643000000
# ...

# %%
maket.head(16)
# Out:
#              1Q2017       2Q2017        3Q2017        4Q2017       1Q2018  \
# 기업명
# 넥슨      31730000000  36500000000   51220000000   59100000000  56310000000
# 엔씨소프트   12701000000  24115000000   22043000000   24151000000  10771000000
# 넷마블     78400000000  82400000000  101000000000  119400000000  74700000000
# 카카오게임즈  24959000000  21929000000   33460000000   36130000000  47941000000
# NHN      2043700000   2087900000    2069000000    2176100000   1593400000
# 컴투스     12020000000  19007000000   13900000000   21300000000  13300000000
# 데브시스터즈   1432000000    325000000      92000000     621000000     34000000
# 그라비티     3007770750   3007770750    3007770750    3007770750   4136462000
# 펄어비스     1254000000   1220000000    1455000000    5212000000  10506000000
# 웹젠       1831000000   2528000000     970000000    1669000000   1735000000
# 네오위즈     3140000000   3153000000    3844000000    3742000000   4217000000
# 위메이드     9059000000   1015000000     563000000     757000000    666000000
# ...

# %%
#기업 별 합계 그래프

maket["합계"].sort_values().plot(kind="bar", figsize=(10,5),grid=True) 

########## 엠게임 수가 너무 적어서 그래프상에 안나오니, 그래프를 위로 키우는게 좋을 것 같아요
# Out:
# <AxesSubplot:xlabel='기업명'>

# %%
#기업 별 합계 그래프

maket["합계"].sort_values().plot(kind="barh", figsize=(10,5),grid=True)
# Out:
# <AxesSubplot:ylabel='기업명'>

# %%
#### 분기별... 합계
#### 분기별 그래프화를 어떻게해야하는지 모르겠습니다...


Total = maket['1Q2017'].sum()
print ("2017년 1분기:",Total)

Total = maket['2Q2017'].sum()
print ("2017년 2분기:",Total)

Total = maket['3Q2017'].sum()
print ("2017년 3분기:",Total)

Total = maket['4Q2017'].sum()
print ("2017년 4분기:",Total) 

print ("\n-------------------------------------\n")

Total = maket['1Q2018'].sum()
print ("2018년 1분기:",Total) 

Total = maket['2Q2018'].sum()
print ("2018년 2분기:",Total) 

Total = maket['3Q2018'].sum()
print ("2018년 3분기:",Total) 

Total = maket['4Q2018'].sum()
print ("2018년 4분기:",Total) 

print ("\n-------------------------------------\n")


Total = maket['1Q2019'].sum()
print ("2019년 1분기:", Total) 

Total = maket['2Q2019'].sum()
print ("2019년 2분기:",Total) 

Total = maket['3Q2019'].sum()
print ("2019년 3분기:",Total) 

Total = maket['4Q2019'].sum()
print ("2019년 4분기:",Total) 

print ("\n-------------------------------------\n")


Total = maket['1Q2020'].sum()
print ("2020년 1분기:",Total) 

Total = maket['2Q2020'].sum()
print ("2020년 2분기:",Total) 

Total = maket['3Q2020'].sum()
print ("2020년 3분기:",Total) 

Total = maket['4Q2020'].sum()
print ("2020년 4분기:",Total) 

print ("\n-------------------------------------\n")


Total = maket['1Q2021'].sum()
print ("2021년 1분기:",Total) 

Total = maket['2Q2021'].sum()
print ("2021년 2분기:",Total) 

Total = maket['3Q2021'].sum()
print ("2021년 3분기:",Total)
# Out:
# 2017년 1분기: 185844362250
# 2017년 2분기: 204504973250
# 2017년 3분기: 237276913250
# 2017년 4분기: 286241342250
#
# -------------------------------------
#
# 2018년 1분기: 241634796250
# 2018년 2분기: 236840957250
# 2018년 3분기: 247320164250
# 2018년 4분기: 276208628250
#
# -------------------------------------
#
# 2019년 1분기: 244800652750
# 2019년 2분기: 259787514750
# 2019년 3분기: 234679277750
# 2019년 4분기: 282093263750
#
# -------------------------------------
#
# 2020년 1분기: 234771647250
# 2020년 2분기: 283822365250
# 2020년 3분기: 323359659250
# 2020년 4분기: 374936031250
#
# -------------------------------------
#
# 2021년 1분기: 287776321000.0
# 2021년 2분기: 383743021000.0
# 2021년 3분기: 428001090000.0

# %%
########## 분기별 그래프

##### 분기별 합계를 행에 추가

maket.loc["분기별 합계", :] = maket.sum(axis = 0)

# %%
maket
# Out:
#               1Q2017        2Q2017        3Q2017        4Q2017        1Q2018  \
# 기업명
# 넥슨      3.173000e+10  3.650000e+10  5.122000e+10  5.910000e+10  5.631000e+10
# 엔씨소프트   1.270100e+10  2.411500e+10  2.204300e+10  2.415100e+10  1.077100e+10
# 넷마블     7.840000e+10  8.240000e+10  1.010000e+11  1.194000e+11  7.470000e+10
# 카카오게임즈  2.495900e+10  2.192900e+10  3.346000e+10  3.613000e+10  4.794100e+10
# NHN     2.043700e+09  2.087900e+09  2.069000e+09  2.176100e+09  1.593400e+09
# 컴투스     1.202000e+10  1.900700e+10  1.390000e+10  2.130000e+10  1.330000e+10
# 데브시스터즈  1.432000e+09  3.250000e+08  9.200000e+07  6.210000e+08  3.400000e+07
# 그라비티    3.007771e+09  3.007771e+09  3.007771e+09  3.007771e+09  4.136462e+09
# 펄어비스    1.254000e+09  1.220000e+09  1.455000e+09  5.212000e+09  1.050600e+10
# 웹젠      1.831000e+09  2.528000e+09  9.700000e+08  1.669000e+09  1.735000e+09
# 네오위즈    3.140000e+09  3.153000e+09  3.844000e+09  3.742000e+09  4.217000e+09
# ...

# %%
##### 그래프 그리기

maket.loc["분기별 합계", :"3Q2021"].plot(kind = "bar")
# Out:
# <AxesSubplot:>
