# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action="ignore")

import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family=font_name)

import matplotlib as mpl
mpl.rcParams["axes.unicode_minus"] = False

import urllib.request as req
from urllib.request import urlopen
from urllib.error import HTTPError, URLError
import urllib.parse
from bs4 import BeautifulSoup
import requests

# %%
game = pd.read_excel("data/gamesales_3companies.xlsx")

# %%
game_pv = game.pivot_table(index=["게임명"], columns="일자", values="매출액", fill_value=0)
game_pv
# Out:
# 일자          2016-03-31   2016-06-30   2016-09-30    2016-12-31    2017-03-31  \
# 게임명
# B&S레볼루션M             0            0            0             0  0.000000e+00
# M                    0            0            0             0  1.907603e+11
# PC                   0            0            0             0  8.028040e+11
# 길드워2       30557000000  15894000000  15315000000   14870000000  1.422600e+10
# 리니지        78877000000  94430000000  83767000000  118414000000  5.146400e+10
# 리니지2       17076000000  19052000000  20591000000   20395000000  1.839900e+10
# 리니지2M                0            0            0             0  0.000000e+00
# 리니지M                 0            0            0             0  0.000000e+00
# 리지니2레볼루션M            0            0            0             0  0.000000e+00
# 마블챔피언M               0            0            0             0  0.000000e+00
# 마블퓨처파이트M             0            0            0             0  0.000000e+00
# 모두의마블M               0            0            0             0  0.000000e+00
# 블레이드앤소울    54018000000  48856000000  40065000000   39382000000  4.456000e+10
# 블레이드앤소울M             0            0            0             0  0.000000e+00
# 세븐나이츠M               0            0            0             0  0.000000e+00
# 아이온        20125000000  17593000000  16067000000   17924000000  1.329400e+10
# 쿠키잼M                 0            0            0             0  0.000000e+00
# 테라M                  0            0            0             0  0.000000e+00
# 해리포터M                0            0            0             0  0.000000e+00
#
# 일자           2017-06-30    2017-09-30    2017-12-31    2018-03-31  \
# 게임명
# B&S레볼루션M   0.000000e+00             0             0             0
# M          1.777153e+11  464281000000  409331000000  346445000000
# PC         6.317480e+11  815612500000  647486000000  650400000000
# 길드워2       1.355700e+10   20145000000   34903000000   23647000000
# 리니지        3.381300e+10   35369000000   33775000000   28268000000
# 리니지2       1.666300e+10   15634000000   15095000000   14233000000
# 리니지2M      0.000000e+00             0             0             0
# 리니지M       0.000000e+00             0             0             0
# 리지니2레볼루션M  1.998370e+11  261765000000  240162000000  177590000000
# 마블챔피언M     7.021300e+10   69804000000   86212000000   81184000000
# 마블퓨처파이트M   0.000000e+00             0   30790000000   25370000000
# 모두의마블M     3.240600e+10   34902000000   30790000000   30444000000
# 블레이드앤소울    3.901000e+10   38046000000   39507000000   33894000000
# 블레이드앤소울M   0.000000e+00             0             0             0
# 세븐나이츠M     4.860900e+10   34902000000   30790000000   30444000000
# 아이온        1.082700e+10   10157000000   12691000000   18761000000
# 쿠키잼M       3.240600e+10   34902000000   36948000000   35518000000
# 테라M        0.000000e+00             0   30790000000             0
# 해리포터M      0.000000e+00             0             0             0
#
# 테라M        0.000000e+00  0.000000e+00  0.000000e+00              0
# 해리포터M      0.000000e+00  0.000000e+00  0.000000e+00              0
#
# 일자            2021-03-31    2021-06-30     2021-09-30
# 게임명
# B&S레볼루션M               0  0.000000e+00              0
# M           649392000000  5.443227e+11   566390000000
# PC         1686850000000  1.060550e+12  1451500000000
# 길드워2         16329000000  1.600400e+10    19199000000
# 리니지          48936000000  3.643900e+10    29147000000
# 리니지2         26209000000  2.417000e+10    25015000000
# 리니지2M       152247000000  2.179890e+11   157857000000
# 리니지M        172637000000  1.341540e+11   150349000000
# 리지니2레볼루션M              0  0.000000e+00              0
# 마블챔피언M                 0  0.000000e+00              0
# 마블퓨처파이트M               0  0.000000e+00              0
# 모두의마블M                 0  0.000000e+00              0
# 블레이드앤소울      14098000000  9.834000e+09    10357000000
# 블레이드앤소울M               0  0.000000e+00    22887000000
# 세븐나이츠M                 0  0.000000e+00              0
# 아이온          23386000000  1.952100e+10    17879000000
# 쿠키잼M                   0  0.000000e+00              0
# 테라M                    0  0.000000e+00              0
# 해리포터M                  0  0.000000e+00              0
#
# [19 rows x 23 columns]

# %%
del game_pv["2016-03-31"], game_pv["2016-06-30"], game_pv["2016-09-30"], game_pv["2016-12-31"] #2016년도 제거

# %%
game_pv.columns=["1Q2017", "2Q2017", "3Q2017", "4Q2017", "1Q2018", "2Q2018", "3Q2018", "4Q2018",
                "1Q2019", "2Q2019", "3Q2019", "4Q2019", "1Q2020", "2Q2020", "3Q2020", "4Q2020",
                "1Q2021", "2Q2021", "3Q2021"] # 일자를 분기로 변경

# %%
####### 체크포인트 추가했습니다

game_pv.to_csv("checkpoint/gamesales_3companies_checkpoint.csv", encoding= "utf=8")

# %%
mobile_names = []
pc_names = []

index_names = game_pv.index
for n in index_names:
    if n[-1] == "M":
        mobile_names.append(n)
    else:
        pc_names.append(n)
        
print(mobile_names)
print("--------------------------------------------")
print(pc_names)

game_pv.loc[mobile_names]
game_pv.loc[pc_names]
# Out:
# ['B&S레볼루션M', 'M', '리니지2M', '리니지M', '리지니2레볼루션M', '마블챔피언M', '마블퓨처파이트M', '모두의마블M', '블레이드앤소울M', '세븐나이츠M', '쿠키잼M', '테라M', '해리포터M']
# --------------------------------------------
# ['PC', '길드워2', '리니지', '리니지2', '블레이드앤소울', '아이온']
#                1Q2017        2Q2017        3Q2017        4Q2017        1Q2018  \
# 게임명
# PC       8.028040e+11  6.317480e+11  815612500000  647486000000  650400000000
# 길드워2     1.422600e+10  1.355700e+10   20145000000   34903000000   23647000000
# 리니지      5.146400e+10  3.381300e+10   35369000000   33775000000   28268000000
# 리니지2     1.839900e+10  1.666300e+10   15634000000   15095000000   14233000000
# 블레이드앤소울  4.456000e+10  3.901000e+10   38046000000   39507000000   33894000000
# 아이온      1.329400e+10  1.082700e+10   10157000000   12691000000   18761000000
#
#                2Q2018        3Q2018        4Q2018        1Q2019        2Q2019  \
# 게임명
# PC       6.093000e+11  9.688375e+11  6.366270e+11  860700000000  7.111500e+11
# 길드워2     1.986000e+10  2.095700e+10  1.569900e+10   16337000000  1.588200e+10
# 리니지      4.208900e+10  4.030300e+10  3.904500e+10   20719000000  5.010900e+10
# 리니지2     1.334000e+10  1.563500e+10  2.067800e+10   21558000000  2.121300e+10
# 블레이드앤소울  3.064700e+10  3.009800e+10  2.499300e+10   23267000000  2.110700e+10
# 아이온      1.561800e+10  1.636700e+10  1.266700e+10   12323000000  1.239100e+10
#
#                3Q2019        4Q2019        1Q2020        2Q2020        3Q2020  \
# 게임명
# PC       9.807000e+11  804250000000  1.479850e+12  1.137050e+12  1.332400e+12
# 길드워2     1.513800e+10   11331000000  1.253000e+10  1.563900e+10  1.881800e+10
# 리니지      5.182900e+10   51413000000  4.475300e+10  3.426400e+10  4.986800e+10
# 리니지2     2.303300e+10   27785000000  2.644300e+10  2.576400e+10  2.633200e+10
# 블레이드앤소울  2.148600e+10   17998000000  1.961700e+10  1.979800e+10  1.721800e+10
# 아이온      1.322400e+10    8064000000  1.014300e+10  8.194000e+09  8.453000e+09
#
#                 4Q2020         1Q2021        2Q2021         3Q2021
# 게임명
# PC       1185350000000  1686850000000  1.060550e+12  1451500000000
# 길드워2       14166000000    16329000000  1.600400e+10    19199000000
# 리니지        46782000000    48936000000  3.643900e+10    29147000000
# 리니지2       25957000000    26209000000  2.417000e+10    25015000000
# 블레이드앤소울    15611000000    14098000000  9.834000e+09    10357000000
# 아이온        18810000000    23386000000  1.952100e+10    17879000000

# %%
mobile = game_pv.loc[mobile_names]
pc = game_pv.loc[pc_names]

# %%
mobile.plot() #게임별로 나눠져 있어서 보기 힘듬
# Out:
# <AxesSubplot:>

# %%
pc.plot() # 이것도 게임별로 나눠져있어서 보기 힘듬
# Out:
# <AxesSubplot:>

# %%
mobile.loc["sum",:] = mobile.sum(axis=0)

# %%
pc.loc["sum",:] = pc.sum(axis=0)

# %%
mobile=mobile.T # 모바일 전치

# %%
pc = pc.T # pc 전치

# %%
plt.figure(figsize=(13,7))
plt.plot(mobile["sum"])

plt.xlabel("분기")
plt.ylabel("매출액")

plt.legend("모바일 총계")

plt.axvline(x = "1Q2020", color = "r")
plt.text('4Q2019',1.200000e+12, "코로나19 발생")
# Out:
# Text(4Q2019, 1200000000000.0, '코로나19 발생')

# %%
plt.figure(figsize=(13,7))
plt.plot(pc["sum"])

plt.xlabel("분기")
plt.ylabel("매출액")

plt.legend("pc 총계")

plt.axvline(x = "1Q2020", color = "r")
plt.text('4Q2019',1.700000e+12, "코로나19 발생")
# Out:
# Text(4Q2019, 1700000000000.0, '코로나19 발생')
